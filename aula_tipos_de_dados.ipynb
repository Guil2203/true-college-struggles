# %% [markdown]
# <a href="https://colab.research.google.com/github/Guil2203/true-college-struggles/blob/main/aula_tipos_de_dados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
z = "HELP"
print(z)
# Out:
# HELP

# %% [markdown]
# yo What is up guys you know WE OUT here Dying
# # ***AAAUUUGH***
#
# > 💬 Squid Games ❗❗
#
#
# things i Enjoy:
# 1.   IDK
# 2.   IDK
# 3.   video james
#
#
#
# ---
#
# legit tho what do i DO

# %%
type(a)
# Out:
# str

# %%
a = 100
b = 25.6
c = a > b
d = "Goomba"
e = 30 == (6*5)
print(a)
print(c)
print(e)
print(d)
# Out:
# 100
# True
# True
# Goomba
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-c33b4fdfaef2> in <module>
#       7 print(c)
#       8 print(e)
# ----> 9 print(d) + ("a")
#
# TypeError: unsupported operand type(s) for +: 'NoneType' and 'str'

# %%
type(b)
# Out:
# float

# %%
# !ls
from IPython.display import Image
Image('picture.png')

# %%
from IPython.core.display import clear_output
# !ls
from IPython.display import Image
clear_output()

minimumScore = 7.0
myScore = 4.0

if(myScore >= minimumScore):
  print("your did it")
elif(myScore >= 4 and minimumScore < 7):
  print("your can still do")
else:
  display(Image('picture.png'))

# %%
minScore = float(input("what's the score i need to get? "))
score1 = float(input("what score did i get? "))
score2 = float(input("put in another one i got "))
score3 = float(input("one last score! "))
average = (score1 + score2 + score3)/3

if(average >= minScore):
  print("congrat ! !")
else:
  display(Image('boowomp.jpg', width=120, height=120))
# Out:
# what's the score i need to get? 7
# what score did i get? 1
# put in another one i got 1
# one last score! 1
